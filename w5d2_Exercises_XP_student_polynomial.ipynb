# %% [markdown]
# <a href="https://colab.research.google.com/github/Lyv-ux/DI_Bootcamp/blob/main/w5d2_Exercises_XP_student_polynomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercises XP: Guided Student Notebook
#
# This guided notebook follows the **exact exercise on the platform**. Cells marked **PREFILLED** are for execution only. Cells marked **To-Do** require your action. When a written answer is required, the **To-Do** appears inside a markdown cell. When code is required, the **To-Do** appears inside a code cell as comments.
#
# Learning points appear only for key concepts to support intuition and transfer to other AI topics.

# %% [markdown]
# ## Reference from the exercise
#
# **What you will learn**
# - The differences between traditional machine learning and deep learning.
# - The structure and working of artificial neural networks. How to generate, visualize, and analyze datasets with noise.
# - Techniques for fitting polynomial regression models and understanding overfitting.
# - The importance of cross-validation in model selection.
#
# **What you will create**
# - A comparative table of traditional machine learning vs deep learning.
# - A simple ANN diagram with labeled components.
# - A noisy dataset visualized with a scatter plot.
# - Polynomial regression models of varying degrees.
# - A cross-validation analysis to select an optimal polynomial degree.

# %% [markdown]
# ## 🌟 Exercise 1: Deep Learning vs Traditional Machine Learning
#
# **As stated in the exercise**
# Objective. Understand the differences between traditional machine learning and deep learning.
# Instructions. Create a table comparing Feature Engineering, Data Processing, Scalability, Pattern Discovery, and Computational Requirements. Identify one real world problem where traditional ML is better, and one where deep learning is better. Write a short paragraph explaining why deep learning has an advantage in unstructured data processing.
#
# **Guidance**
# Use a markdown table for the comparison, keep wording concise and concrete, then write two short examples and one paragraph in full sentences.
#
# **To-Do:** Complete the comparison table below by filling in each cell with your own wording.

# %% [markdown]
# | Aspect | Traditional ML | Deep Learning |
# |:--|:--|:--|
# | Feature Engineering | Manuel : Nécessite une intervention humaine et une expertise métier pour extraire et sélectionner les variables pertinentes avant l'entraînement. | Automatique : Le modèle apprend et extrait lui-même les caractéristiques utiles directement à partir des données brutes |
# | Data Processing | Préfère les données structurées (tableaux, bases de données relationnelles) et nécessite un nettoyage rigoureux des valeurs manquantes ou aberrantes. | Excelle avec les données non structurées (images, textes, audio) et gère de larges volumes de données brutes.|
# | Scalability | Atteint rapidement un plateau de performance ; ajouter plus de données n'améliore plus le modèle au-delà d'un certain seuil. | Hautement évolutif : Les performances s'améliorent continuellement à mesure que le volume de données augmente.|
# | Pattern Discovery | Limité à la découverte de relations et de motifs linéaires ou de complexité modérée au sein de variables prédéfinies. | Capable de détecter des motifs hautement complexes, non linéaires et abstraits cachés dans de très grandes dimensions. |
# | Computational Requirements | Faibles à modérés : S'entraîne rapidement sur un processeur classique (CPU) avec une consommation d'énergie et de mémoire réduite. | Très élevés : Nécessite obligatoirement des architectures matérielles spécialisées (GPU, TPU) et des temps d'entraînement parfois longs.|

# %% [markdown]
# **To-Do:** Give one real world problem better suited to traditional ML and one better suited to deep learning. Explain your choices in 2–3 sentences.

# %% [markdown]
# Traditional Machine Learning: Customer Churn Prediction
# Problem: Predicting whether a customer will cancel a subscription based on historical tabular data (e.g., tenure, monthly spend, and customer service call logs).
#
# Explanation: This structured data is perfectly optimized for tree-based traditional machine learning algorithms like XGBoost or Random Forests. These models train rapidly on smaller tabular datasets and provide crucial feature importances, allowing businesses to easily interpret why a customer is leaving and take targeted action.
#
# Deep Learning: Automated Medical Image Segmentation
# Problem: Identifying and outlining the exact boundaries of a tumor from a high-resolution MRI scan.
#
# Explanation: High-dimensional, unstructured data like images lacks explicit tabular features and possesses spatial relationships that traditional algorithms cannot naturally parse. Deep learning models, specifically Convolutional Neural Networks (CNNs), excel at automatically learning complex hierarchies of visual features (edges, textures, and shapes) directly from raw pixels to achieve human-level precision.

# %% [markdown]
# **To-Do:** Write a paragraph of 3–5 sentences explaining why deep learning has an advantage in unstructured data processing, using precise terms such as representation learning and hierarchical features.

# %% [markdown]
# Deep learning excels at processing unstructured data because it fundamentally eliminates the need for manual, human-engineered feature extraction through a process known as representation learning. Instead of relying on predefined rules, deep neural networks automatically discover the underlying patterns within raw data by passing it through multiple interconnected layers. Each successive layer builds upon the last to construct a system of hierarchical features, starting from low-level edges or frequencies and progressively assembling them into high-level, abstract concepts. This ability to capture complex, non-linear relationships directly from raw inputs allows deep learning models to achieve unparalleled accuracy in tasks like computer vision and natural language processing, where traditional algorithms struggle to parse the inherent lack of rigid structure.

# %% [markdown]
# ## 🌟 Exercise 2: Artificial Neural Networks (ANNs)
#
# **As stated in the exercise**
# Objective. Identify and understand the key components of an ANN.
# Instructions. Draw or use a diagram tool to create an ANN with an input layer of 3 neurons, one hidden layer of 4 neurons, and an output layer of 2 neurons. Label neurons, weights, biases, activation function, and layers. Write a short description of how information flows through the network.
#
# **Guidance**
# A clear schematic is preferred. Ensure every requested label appears exactly once and is readable.

# %% [markdown]
# **To-Do:** Provide a 3–5 sentence description of forward propagation in your diagram. Refer explicitly to inputs, weighted sums, biases, activation, and outputs.

# %% [markdown]
# La propagation avant commence lorsque les données d'entrée (inputs) (ici, IN1 à IN3) sont présentées à la première couche du réseau. Chaque neurone de la couche cachée reçoit une combinaison de ces entrées, modifiée par les poids (ex. : $w_{1,1}$) des connexions, à laquelle un biais est ajouté. Ce calcul donne une somme pondérée (weighted sum). Cette somme passe ensuite par une fonction d'activation (comme ReLU, illustrée ici par une courbe), qui détermine l'activation finale du neurone, c'est-à-dire sa sortie. Ce processus de transformation affine suivi d'une non-linéarité se répète à travers les couches jusqu'à ce que les données de sortie (outputs) (OUT1, OUT2) soient générées.

# %% [markdown]
# **Learning point**
# An ANN composes affine transformations with nonlinear activations. The affine part mixes features through weights and biases. The nonlinearity enables modeling of complex decision boundaries.

# %% [markdown]
# ## 🌟 Exercise 3: Creating the Dataset and Visualizing the Data
#
# **As stated in the exercise**
# Objective. Generate a dataset with noise and visualize it.
# Instructions. Import numpy, matplotlib.pyplot, and mean_squared_error from sklearn.metrics. Create 20 points using \(y = -x^2\) with Gaussian noise \(\mathcal{N}(0, 0.05)\). Plot the points with a scatter plot. Split into a training set with the first 12 points and a test set with the last 8 points.

# %%
# PREFILLED: just execute
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

np.random.seed(0)
x = np.arange(-1, 1, 0.1)  # 20 points from -1 to <1 step 0.1
print("x shape:", x.shape)
# Out:
# x shape: (20,)

# %%
# To-Do: generate y with noise using np.random.normal()
# y = ...
# print("y shape:", y.shape)

# %%
y = -x**2 + np.random.normal(loc=0, scale=0.05, size=x.shape)
print("y shape:", y.shape)
# Out:
# y shape: (20,)

# %%
# PREFILLED: just execute (scatter plot of the dataset)
plt.figure(figsize=(5,4))
plt.scatter(x, y)
plt.title("Noisy dataset sampled from y = -x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.tight_layout()
plt.show()

# %%
x_train, y_train = x[:12], y[:12]
x_test,  y_test  = x[12:], y[12:]
print("train sizes:", x_train.shape, y_train.shape, "test sizes:", x_test.shape, y_test.shape)
# Out:
# train sizes: (12,) (12,) test sizes: (8,) (8,)

# %% [markdown]
# **Learning point**
# Visualizing noisy data helps separate signal from noise. Splitting into train and test allows you to detect when a model overfits noise instead of learning the underlying pattern.

# %% [markdown]
# ## 🌟 Exercise 4: Fitting Polynomial Models of Different Degrees
#
# **As stated in the exercise**
# Objective: Fit polynomial models of varying degrees and observe overfitting.
#
# Instructions: Define `polynomial_fit(degree)` that returns the fitted polynomial coefficients from training data. Define `plot_polyfit(degree)` that draws the training set, the test set, and the fitted polynomial curve. Visualize fits for degrees 1, 7, and 11. Observe behavior on training and test sets as degree increases.

# %%
def polynomial_fit(degree: int):
    # Use np.polyfit to get coefficients from training data
    coeffs = np.polyfit(x_train, y_train, degree)
    # Use np.poly1d to create a callable polynomial function
    return np.poly1d(coeffs)

# %%
import numpy as np
import matplotlib.pyplot as plt
def plot_polyfit(degree: int):
    # 1) fit
    poly = polynomial_fit(degree)

    # 2) create a dense linspace over x range
    x_range = np.linspace(x.min(), x.max(), 100)

    # 3) evaluate fitted polynomial
    y_poly = poly(x_range)

    # 4) scatter train and test, and plot curve
    plt.figure(figsize=(6,4))
    plt.scatter(x_train, y_train, label='Training Data', color='blue')
    plt.scatter(x_test, y_test, label='Test Data', color='red')
    plt.plot(x_range, y_poly, label=f'Polynomial (degree {degree})', color='green', linestyle='--')

    # 5) display
    plt.title(f'Polynomial Fit (Degree {degree})')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
plot_polyfit(1)
plot_polyfit(7)
plot_polyfit(11)

# %% [markdown]
# **Learning point**
# Higher degree polynomials can perfectly fit training data yet fail to generalize. This is overfitting. You should always check test error, not just training error.
#
# ![image.png](https://github.com/user-attachments/assets/cdfb495c-066a-4efb-a361-f4b9d4ade35c)

# %% [markdown]
# ## 🌟 Exercise 5: Cross-Validation to Find the Optimal Degree
#
# **As stated in the exercise**
# Objective: Use cross-validation to determine the best polynomial degree.
#
# Instructions: Loop degrees from 1 to 11. For each degree, compute the RMSE on the training and test sets. Store results in a list. Plot RMSE vs degree with a logarithmic y axis. Identify the degree minimizing test RMSE and confirm it matches the true model \(y=-x^2\).

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

degrees = range(1, 12)
rows = []  # each row: (degree, rmse_train, rmse_test)
for d in degrees:
    # fit on train
    poly = polynomial_fit(d)

    # evaluate on train and test
    y_train_pred = poly(x_train)
    y_test_pred = poly(x_test)

    rmse_train = rmse(y_train, y_train_pred)
    rmse_test = rmse(y_test, y_test_pred)

    # append to rows
    rows.append((d, rmse_train, rmse_test))

print(rows[:3])  # peek
# Out:
# [(1, np.float64(0.1002263344864799), np.float64(1.0240708833556866)), (2, np.float64(0.04114590494650985), np.float64(0.12578064282386534)), (3, np.float64(0.037336922311085964), np.float64(0.769651993080075))]

# %%
degs = [r[0] for r in rows]
rmse_tr = [r[1] for r in rows]
rmse_te = [r[2] for r in rows]
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.plot(degs, rmse_tr, label="train RMSE")
plt.plot(degs, rmse_te, label="test RMSE")
plt.yscale("log")
plt.xlabel("polynomial degree")
plt.ylabel("RMSE")
plt.title("RMSE vs degree")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **To-Do:** Report the degree with the minimum test RMSE and explain in 2–3 sentences how this connects to the true model \(y=-x^2\) and the bias–variance trade off.

# %%
min_test_rmse = float('inf')
optimal_degree = -1

for degree, train_rmse, test_rmse in rows:
    if test_rmse < min_test_rmse:
        min_test_rmse = test_rmse
        optimal_degree = degree

print(f"The degree with the minimum test RMSE is: {optimal_degree}")
print(f"Minimum test RMSE: {min_test_rmse:.4f}")
# Out:
# The degree with the minimum test RMSE is: 2
# Minimum test RMSE: 0.1258

# %% [markdown]
# The degree with the minimum test RMSE was **2**. This makes perfect sense, as the true underlying model for the data generation was $y = -x^2$, which is a polynomial of degree 2.
#
# In terms of the bias-variance trade-off, a polynomial of degree 2 effectively captures the true underlying relationship (low bias) without fitting to the noise in the training data (low variance). Lower degrees would suffer from high bias (underfitting), as they are too simple to represent the quadratic relationship. Higher degrees, while achieving very low training RMSE, exhibit high variance (overfitting) by trying to fit every noisy point, leading to poor generalization and high test RMSE.
