# %% [markdown]
# <a href="https://colab.research.google.com/github/Lyv-ux/DI_Bootcamp/blob/main/W6D5_MiniProjet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Training
EPOCHS = 2

history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=EPOCHS
)

# Evaluation
eval_metrics = model.evaluate(test_ds)

print("\nTest Results:")
print(eval_metrics)

# Inference helper
def predict_sentiment(text: str):

    encoded = tokenizer(
        text,
        max_length=MAX_LENGTH,
        padding="max_length",
        truncation=True,
        return_tensors="tf"
    )

    logits = model(encoded).logits

    probs = tf.nn.softmax(logits, axis=-1).numpy()[0]

    prediction = probs.argmax()

    label = "Positive" if prediction == 1 else "Negative"

    return label, float(probs.max())

custom_sentence = "The onboarding emails were confusing, but the agent fixed everything politely."

label, confidence = predict_sentiment(custom_sentence)

print(f"Prediction: {label} (confidence={confidence:.3f})")
