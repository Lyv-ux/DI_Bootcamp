# %% [markdown]
# 🌟Exercise 1: Introduction to Data Analysis (Easy)

# %% [markdown]
# What is data analysis?
#    _Data analysis is collecting, "interrogating" and analysing data to find useful informations for a specific purpose
# Why is data analysis important in modern contexts?
#     _Data analysis is important in modern contexts because it can significantly helps to reach an objective.
# List and describe three areas where data analysis is applied today.
#     _Business, HealthCare, Public Policy.

# %% [markdown]
# 🌟Exercise 2: Dataset Loading and Initial Analysis and 🌟Exercise 3: Identifying Data Types

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into Jupyter or Google Colab.

# %%
Mental_Health= pd.read_csv('Mental health Depression disorder Data.csv', index_col=0, low_memory=False)
Time_Americans= pd.read_csv('Time Americans Spend Sleeping.csv', index_col=0)
crx = pd.read_csv('crx.csv')
clean_dataset = pd.read_csv('clean_dataset.csv')

# %% [markdown]
# Display the first few rows and Provide a brief dataset description.

# %%
Time_Americans.head()
# Out:
#        Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# index
# 0      2003  Annual                      8.57           0.018     All days
# 1      2004  Annual                      8.55           0.026     All days
# 2      2005  Annual                      8.62           0.023     All days
# 3      2006  Annual                      8.63           0.024     All days
# 4      2007  Annual                      8.57           0.024     All days
#
#                Age Group  Activity   Sex
# index
# 0      15 years and over  Sleeping  Both
# 1      15 years and over  Sleeping  Both
# 2      15 years and over  Sleeping  Both
# 3      15 years and over  Sleeping  Both
# 4      15 years and over  Sleeping  Both

# %% [markdown]
# In this dataset,
#         Qualitative Columns are: Period, Activity, Sex, Types of days, Age Group because they are non-numerical datas.
#
#         Quantitative Colums are: Year, Avg per day sleeping.

# %% [markdown]
# This is a file showing the Average American's Time Sleeping

# %%
Mental_Health.head()
# Out:
#             Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# index
# 0      Afghanistan  AFG  1990           0.16056             0.697779
# 1      Afghanistan  AFG  1991          0.160312             0.697961
# 2      Afghanistan  AFG  1992          0.160135             0.698107
# 3      Afghanistan  AFG  1993          0.160037             0.698257
# 4      Afghanistan  AFG  1994          0.160022             0.698469
#
#       Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# index
# 0                 0.101855               4.828830                1.677082
# 1                 0.099313               4.829740                1.684746
# 2                 0.096692               4.831108                1.694334
# 3                 0.094336               4.830864                1.705320
# 4                 0.092439               4.829423                1.716069
#
#        Depression (%)  Alcohol use disorders (%)
# index
# ...

# %% [markdown]
# This is a file showing world mental and physical disorders datas.

# %% [markdown]
# The qualitative columns are: Entity  and Code because they are strings.
# All other columns are quantitative because they are numerical.

# %%
crx.head()
# Out:
#    b  30.83      0  u  g  w  v  1.25  t t.1  01  f g.1  00202  0.1  +
# 0  a  58.67  4.460  u  g  q  h  3.04  t   t   6  f   g  00043  560  +
# 1  a  24.50  0.500  u  g  q  h  1.50  t   f   0  f   g  00280  824  +
# 2  b  27.83  1.540  u  g  w  v  3.75  t   t   5  t   g  00100    3  +
# 3  b  20.17  5.625  u  g  w  v  1.71  t   f   0  f   s  00120    0  +
# 4  b  32.08  4.000  u  g  m  v  2.50  t   f   0  t   g  00360    0  +

# %%
clean_dataset.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %% [markdown]
# Quantitative columns are all numerical columns except Married and Approved because they represent a statut.
# All other columns are qualitative

# %% [markdown]
# This is a file showing Bank Approvals

# %% [markdown]
# 🌟Exercise 4: Exploring Data Types

# %%
iris = pd.read_csv('Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Id, SepalLength, SepalWidthCm and PetalWitdthcm are quantitative because because they are numerical.
# Species is qualitative because it's text, it's a label

# %% [markdown]
# 🌟Exercise 5: Basic Observation Skills in Data Analysis

# %%
Time_Americans
# Out:
#        Year  Period  Avg hrs per day sleeping  Standard Error  \
# index
# 0      2003  Annual                      8.57           0.018
# 1      2004  Annual                      8.55           0.026
# 2      2005  Annual                      8.62           0.023
# 3      2006  Annual                      8.63           0.024
# 4      2007  Annual                      8.57           0.024
# ...     ...     ...                       ...             ...
# 940    2013  Annual                      8.83           0.085
# 941    2014  Annual                      8.98           0.086
# 942    2015  Annual                      8.83           0.074
# 943    2016  Annual                      8.92           0.071
# 944    2017  Annual                      8.81           0.091
#
#               Type of Days          Age Group  Activity    Sex
# index
# 0                 All days  15 years and over  Sleeping   Both
# 1                 All days  15 years and over  Sleeping   Both
# ...

# %% [markdown]
# We can for instance use:
#    _Colums Sex and Avg hrs per day to know which sex sleep more.
#    _Columns Year and Avg hrs per day pto know if people sleep less now or not

# %% [markdown]
# 🌟 Exercise 6: Identifying Data Types
#
# A company’s financial reports stored in an Excel file: Structured Data
# Photographs uploaded to a social media platform: Unstructured Data
# A collection of news articles on a website: Structured Data
# Inventory data in a relational database: Structured Data
# Recorded interviews from a market research study: Unstructured Data

# %% [markdown]
# 🌟 Exercise 7: Transformation Exercise
#
# For each of the following unstructured data sources, propose a method to convert it into structured data. Explain your reasoning.
#
# A series of blog posts about travel experiences: We could gather the posts based on the destinations.
# Audio recordings of customer service calls: We could gather the audio based on the recording hour or the purpose.
# Handwritten notes from a brainstorming session: We could gather the notes bases on who wrote it.
# A video tutorial on cooking: We could Separate the video by sections. Example: peelingd of fruits is from...to...

# %% [markdown]
# 🌟 Exercise 8 : Import a file from Kaggle

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 🌟 Exercise 9 : Export a dataframe to excel format and JSON format.

# %%
simple_dataframe = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 32],
    'City': ['New York', 'Paris', 'Berlin', 'London']
}
df = pd.DataFrame(simple_dataframe)
df

df.to_excel('simple_data.xlsx', index=False)
df.to_json('simple_dataframe.json')

# %% [markdown]
# 🌟 Exercise 10: Reading JSON Data

# %%
json_data = pd.read_json('posts.json')
json_data.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
