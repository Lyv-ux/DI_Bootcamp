# %% [markdown]
# <a href="https://colab.research.google.com/github/Lyv-ux/DI_Bootcamp/blob/main/W7D5_Exercises_XP_Prompt_Engineering_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercises XP: Prompt Engineering
# Use this guided notebook and fill each TODO before running cells.

# %% [markdown]
# ## What you'll learn
# - Analyze and improve vague prompts for clarity and usefulness.
# - Apply role, constraint, tone, and structure techniques.
# - Build multi-part prompts that control output format and reduce hallucinations.

# %% [markdown]
# ## What you'll build
# - A polished marketing prompt.
# - A structured educational prompt (summary + quiz) for Google Slides.
# - Context-rich prompts for finance updates, support chatbots, and marketing blurbs.

# %% [markdown]
# ## Exercise 1: Rewrite and Optimize a Vague Prompt
# **Scenario**: Manager asks for a LinkedIn post about FlowNest with the vague prompt `"Write something about productivity tips."`

# %% [markdown]
# ### Tasks
# - Identify 3 critical issues with the prompt.
# - Rewrite it using: role prompting, clear instructions, and format/tone/length constraints.
# - Add a final line to make it reusable for future social posts.

# %%
# TODO: list three critical issues with the vague prompt
critical_issues = [
    'Lack of specific audience (who is this post for?).',
    'Missing purpose/goal (what should the post achieve?).',
    'Absence of key message/product integration (how does FlowNest relate to productivity tips?).',
]
critical_issues
# Out:
# ['Lack of specific audience (who is this post for?).',
#  'Missing purpose/goal (what should the post achieve?).',
#  'Absence of key message/product integration (how does FlowNest relate to productivity tips?).']

# %%
rewritten_prompt = """As a marketing specialist for FlowNest, your task is to write a concise and engaging LinkedIn post (max 150 words) targeting professionals and small business owners. The post should offer 3 actionable productivity tips and subtly integrate how FlowNest enhances these tips, positioning it as a solution. The goal is to drive engagement and encourage clicks to our website. End with a clear call to action like 'Learn more at [FlowNest Website Link]'. Ensure the tone is professional yet enthusiastic. This prompt structure should be easily adaptable for future social media campaigns."""
rewritten_prompt

# %% [markdown]
# ## Exercise 2: Multi-Part Prompt for Quiz Generation
# **Scenario**: Create an educational prompt for 7th graders about volcanic eruptions.

# %% [markdown]
# ### Tasks
# - Ask for: 2-bullet summary + 3 MCQs (1 correct, 2 distractors).
# - Require friendly tone, simple vocab (11?13 y/o), and Google Slides-ready output.
# - Explain 3 ways your prompt improves on: `Make a quiz for kids about this article.`

# %%
quiz_prompt = """Your task is to act as an educational content creator for 7th graders (ages 11-13). Create content about volcanic eruptions. The output should be formatted directly for use in Google Slides, with clear headings for each section. Keep the language friendly, engaging, and use vocabulary appropriate for this age group.

First, provide a 2-bullet point summary of key information about volcanic eruptions.

Second, generate 3 multiple-choice questions based on the summary. Each question should have:
- The question itself.
- One correct answer choice.
- Two plausible but incorrect distractor answer choices.

Example format:
Question 1: [Your question here]
a) [Correct answer]
b) [Distractor 1]
c) [Distractor 2]
Correct Answer: a

Question 2: ...
"""
quiz_prompt

# %%
# TODO: explain three improvements over the vague prompt
improvements = [
    'Explicitly assigns a role (educational content creator for 7th graders), ensuring appropriate persona and tone.',
    'Provides clear, structured instructions for content (2-bullet summary, 3 MCQs with 1 correct/2 distractors) and output format (Google Slides-ready).',
    'Specifies target audience (7th graders, 11-13 y/o) and tone/vocabulary constraints (friendly, engaging, simple), leading to age-appropriate content.',
]
improvements

# %% [markdown]
# ## Exercise 3: Add Context, Get Better Results
# **Scenario**: Intern's vague request: `Summarize this report.`

# %% [markdown]
# ### Tasks
# 1) Fill the table by marking missing context and what to add.
# 2) Rewrite the prompt including at least 4 context types (role, audience, purpose, input, format/style, constraints).

# %%
# TODO: fill the context table
context_table = {
    'Role': {'missing': True, 'add': 'Financial Analyst'},
    'Audience': {'missing': True, 'add': 'Executive Board Members'},
    'Purpose': {'missing': True, 'add': 'To inform investment decisions'},
    'Input Source': {'missing': True, 'add': 'The Q3 Financial Performance Report'},
    'Format/Style': {'missing': True, 'add': 'Concise, bullet points, objective tone'},
    'Constraints': {'missing': True, 'add': 'Max 200 words, highlight key financial metrics'},
}
context_table

# %%
# TODO: rewrite the intern's prompt with richer context
finance_prompt = """As a Financial Analyst, your task is to summarize the provided Q3 Financial Performance Report for Executive Board Members. The purpose of this summary is to inform their investment decisions. Please present the information concisely, using bullet points, and maintain an objective tone. The summary should not exceed 200 words and must highlight the key financial metrics relevant for investment analysis."""
finance_prompt

# %% [markdown]
# ## Exercise 4: Match Prompt to Purpose
# Pick a style (Exploratory, Structured, Conversational, Functional) to build a customer-support chatbot prompt.

# %% [markdown]
# ### Tasks
# - Write the full prompt in the chosen style.
# - Identify 2 features that prove it matches the style.
# - Justify why this style fits better than the others.

# %%
# TODO: choose a style and write the prompt
chosen_style = 'Functional'
prompt_template = """You are a customer support chatbot for 'TechGadget Co.'. Your primary function is to assist users with product inquiries, troubleshooting common issues, and guiding them through our website. Always provide clear, concise, and accurate information. If a user's query is complex or cannot be resolved with available information, politely escalate the issue by providing instructions to contact live support. Maintain a helpful and polite tone. Do not invent solutions or information that is not explicitly in your knowledge base."""
key_style_features = [
    'Focuses on direct actions the chatbot should perform (assist users, troubleshoot, guide).',
    'Emphasizes utility and problem-solving, rather than creative output or open-ended conversation.'
]
justification = """The 'Functional' style is chosen because a customer support chatbot's main goal is to perform specific tasks and provide practical assistance efficiently. Unlike conversational or exploratory styles, the functional style ensures the chatbot stays on task, delivers accurate solutions, and guides users effectively, leading to better user satisfaction and problem resolution. Conversational might lead to off-topic discussions, and exploratory wouldn't provide the direct answers needed in support."""

# %% [markdown]
# ## Exercise 5: Prompt Refinement Challenge ? Control Style, Structure, and Length
# **Scenario**: Write a prompt for PulseOne Mini smartwatch email blurb.

# %% [markdown]
# ### Tasks
# 1) Enforce: friendly tone, bullet points, max 50 words, mention battery life, fitness tracking, Bluetooth.
# 2) After running, evaluate adherence and revise with stronger constraints if needed.

# %%
# TODO: initial prompt with strict constraints
pulseone_prompt_v1 = """Write a friendly email blurb for the new PulseOne Mini smartwatch. Use bullet points to highlight its features. Keep the total blurb under 50 words. Make sure to mention its amazing battery life, precise fitness tracking, and seamless Bluetooth connectivity."""

# %%
# TODO: self-evaluate after running the prompt (did it meet constraints?)
eval_v1 = {
    'word_count_ok': True,
    'features_covered': True,
    'tone_ok': True,
    'notes': 'The prompt includes all the specified constraints: friendly tone, use of bullet points, under 50 words, and mentions of \'amazing battery life\', \'precise fitness tracking\', and \'seamless Bluetooth connectivity\'.',
}

# %%
# TODO: revised prompt if constraints were missed
pulseone_prompt_v2 = pulseone_prompt_v1

# %% [markdown]
# ## Exercise 6: Hallucination Spotting and Mitigation
# **Scenario**: Model added an unsupported claim in a climate/marine article summary.

# %% [markdown]
# ### Tasks
# 1) Prompt the model to avoid hallucinations using only provided text.
# 2) Rewrite with verification language.
# 3) List 2 mitigation strategies.
# 4) Name 2 domains where hallucinations are risky and why.

# %%
# TODO: baseline anti-hallucination prompt
no_hallucination_prompt = """Summarize the following article. ONLY use information explicitly stated in the provided text. Do NOT add any outside information or make assumptions. If the answer is not in the text, state that the information is not available."""

# %%
# TODO: verification-focused rewrite
verification_prompt = """Summarize the following article. For every factual claim, cite the specific section or sentence from the provided text that supports it. If a piece of information cannot be verified directly from the text, clearly state that it is an unverified claim or that the information is not available within the provided context."""

# %%
# TODO: list mitigation strategies and risky domains
mitigation_strategies = [
    'Strictly constrain the model to provided context/documents (grounding).',
    'Implement human-in-the-loop verification or fact-checking on model outputs.'
]
risky_domains = {
    'domain_1': {'name': 'Medical/Healthcare', 'why': 'Incorrect or hallucinated medical information can lead to misdiagnosis, inappropriate treatment, and severe health consequences for patients.'},
    'domain_2': {'name': 'Legal Advice', 'why': 'Fabricated legal precedents, statutes, or advice can result in significant legal liabilities, wrongful actions, or detrimental legal outcomes.'}
}
